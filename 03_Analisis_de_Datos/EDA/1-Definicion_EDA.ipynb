# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# ### TÍTULO

# %%
#Escribe el título del proyecto en Markdown
titulo = "Hazte con el mejor!"

# %% [markdown]
# ### TEMA

# %%
# Describe brevemente el tema del proyecto en Markdown
tema = "Pokémon"

# %% [markdown]
# ### HIPÓTESIS

# %% [markdown]
# Define aquí lo que será la hipótesis de tu proyecto.
# Deberás tener más de una, pero tu proyecto lo harás teniendo una principal hipótesis.

# %%
# Escribe tu hipótesis principal en Markdown
hipotesis_1 = "pokémon más popular a lo largo del tiempo"

# %%
# Escribe más hipótesis si las hubiera en Markdown
# hipotesis_2 = "generacion pokemon que más gusta"
# hipotesis_3 = "relacion entre estadisticas y el tipo de pokemon"
# hipotesis_4 = "relación que tiene el cambio en la apariencia de los pokemon a lo largo del tiempo con su grado de aceptacion"
# hipotesis_5 = "tipo mas comun"
# hipotesis_6 =  'Rareza de los pokemon legendarios'
# hipotesis_7 = 'relacion 'tier list' con las caracteristicas del pokemon, solo los mejores tienen sitio en el competitivo?'

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una vista del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
# Hacer una solicitud GET a la página web
url = 'https://vandal.elespanol.com/noticia/1350766721/estos-son-los-juegos-de-pokemon-mas-vendidos-de-todos-los-tiempos-cual-es-el-numero-1/'
respuesta = requests.get(url)


# Encontrar las etiquetas de encabezado de la tabla
encabezados = tabla.find_all('th')
nombres_columnas = [encabezado.text.strip() for encabezado in encabezados]

# Crear una lista para almacenar los datos
datos = []

# Iterar sobre las filas y extraer los datos de las celdas
for fila in filas:
    celdas = fila.find_all('td')
    fila_datos = [celda.text.strip() for celda in celdas]
    datos.append(fila_datos)

# Crear un DataFrame con los datos extraídos y los nombres de las columnas
df = pd.DataFrame(datos[1:], columns=nombres_columnas)

# Mostrar el DataFrame
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 10
#       6 respuesta = requests.get(url)
#       9 # Encontrar las etiquetas de encabezado de la tabla
# ---> 10 encabezados = tabla.find_all('th')
#      11 nombres_columnas = [encabezado.text.strip() for encabezado in encabezados]
#      13 # Crear una lista para almacenar los datos
#
# NameError: name 'tabla' is not defined

# %%
import requests
from bs4 import BeautifulSoup
from simplejson import JSONDecodeError

# Hacer una solicitud GET a la página web
url = 'https://www.millenium.gg/noticias/32528.html'
respuesta = requests.request(url= url, method= 'GET')
# Crear un objeto BeautifulSoup para analizar el HTML
soup = BeautifulSoup(respuesta.text, 'lxml')

# Encontrar las etiquetas de encabezado de la tabla
encabezados = tabla.find_all('th')
nombres_columnas = [encabezado.text.strip() for encabezado in encabezados]

# Crear una lista para almacenar los datos
datos = []

# Iterar sobre las filas y extraer los datos de las celdas
for fila in filas:
    celdas = fila.find_all('td')
    fila_datos = [celda.text.strip() for celda in celdas]
    datos.append(fila_datos)

# Crear un DataFrame con los datos extraídos y los nombres de las columnas
df1 = pd.DataFrame(datos[1:], columns=nombres_columnas)

# Mostrar el DataFrame
df1
# Out:
#      #                                           Juego   Ańo  \
# 0    1                             Pokémon Rojo y Azul  1996
# 1    2                         Pokémon Espada y Escudo  2019
# 2    3                             Pokémon Oro y Plata  1999
# 3    4                     Pokémon Escarlata y Púrpura  2022
# 4    5                         Pokémon Diamond & Pearl  2006
# 5    6                                     Pokémon X/Y  2013
# 6    7                           Pokémon Rubí y Zafiro  2002
# 7    8                              Pokémon Sol y Luna  2016
# 8    9                  Pokémon Edición Negra y Blanca  2010
# 9   10  Pokémon: Let's Go, Pikachu! / Let's Go, Eevee!  2018
# 10  11   Pokémon Diamante Brillante / Perla Reluciente  2021
# 11  12                         Leyendas Pokémon Arceus  2022
# 12  13                                Pokémon Amarillo  1998
# 13  14                Pokémon Rubí Omega & Zafiro Alfa  2014
# 14  15              Pokémon Heart Gold and Soul Silver  2009
# 15  16                 Pokémon Rojo Fuego y Verde Hoja  2004
# 16  17                    Pokémon Ultrasol / Ultraluna  2017
# 17  18                Pokémon Edición Negra y Blanca 2  2012
# 18  19                                 Pokémon Platino  2008
# 19  20                                 Pokémon Cristal  2000
# 20  21                               Pokémon Esmeralda  2004
#
#    Ventas a nivel mundial        Plataforma
# 0          31,37 millones          Game Boy
# 1          26,02 millones   Nintendo Switch
# 2          23,73 millones    Game Boy Color
# 3          23,23 millones   Nintendo Switch
# 4          17,67 millones       Nintendo DS
# 5          16,45 millones      Nintendo 3DS
# 6          16,22 millones  Game Boy Advance
# 7          16,18 millones      Nintendo 3DS
# 8          15,64 millones       Nintendo DS
# 9          15,07 millones   Nintendo Switch
# 10         14,92 millones   Nintendo Switch
# 11         14,83 millones   Nintendo Switch
# 12         14,64 millones          Game Boy
# 13         14,27 millones      Nintendo 3DS
# 14         12,72 millones       Nintendo DS
# 15            12 millones  Game Boy Advance
# 16          8,77 millones      Nintendo 3DS
# 17          7,63 millones       Nintendo DS
# 18          7,06 millones       Nintendo DS
# 19          6,39 millones    Game Boy Color
# 20          6,32 millones  Game Boy Advance

# %%
import csv 
import seaborn as sns
import pandas as pd

pokemon = pd.read_csv('pokemon (1).csv')
pokemon2 = pd.read_csv('Pokemon_alopez247.csv')
pokemon
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 5
#       2 import seaborn as sns
#       3 import pandas as pd
# ----> 5 pokemon = pd.read_csv('pokemon (1).csv')
#       6 pokemon2 = pd.read_csv('Pokemon_alopez247.csv')
#       7 pokemon
#
# File c:\Users\buque\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\buque\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\buque\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\buque\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\buque\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'pokemon (1).csv'

# %%
pokemon2
# Out:
#      Number        Name   Type_1  Type_2  Total   HP  Attack  Defense  Sp_Atk  \
# 0         1   Bulbasaur    Grass  Poison    318   45      49       49      65
# 1         2     Ivysaur    Grass  Poison    405   60      62       63      80
# 2         3    Venusaur    Grass  Poison    525   80      82       83     100
# 3         4  Charmander     Fire     NaN    309   39      52       43      60
# 4         5  Charmeleon     Fire     NaN    405   58      64       58      80
# ..      ...         ...      ...     ...    ...  ...     ...      ...     ...
# 716     717     Yveltal     Dark  Flying    680  126     131       95     131
# 717     718     Zygarde   Dragon  Ground    600  108     100      121      81
# 718     719     Diancie     Rock   Fairy    600   50     100      150     100
# 719     720       Hoopa  Psychic   Ghost    600   80     110       60     150
# 720     721   Volcanion     Fire   Water    600   80     110      120     130
#
#      Sp_Def  ...   Color  hasGender  Pr_Male   Egg_Group_1  Egg_Group_2  \
# 0        65  ...   Green       True    0.875       Monster        Grass
# 1        80  ...   Green       True    0.875       Monster        Grass
# 2       100  ...   Green       True    0.875       Monster        Grass
# 3        50  ...     Red       True    0.875       Monster       Dragon
# 4        65  ...     Red       True    0.875       Monster       Dragon
# ..      ...  ...     ...        ...      ...           ...          ...
# 716      98  ...     Red      False      NaN  Undiscovered          NaN
# 717      95  ...   Green      False      NaN  Undiscovered          NaN
# 718     150  ...    Pink      False      NaN  Undiscovered          NaN
# 719     130  ...  Purple      False      NaN  Undiscovered          NaN
# 720      90  ...   Brown      False      NaN  Undiscovered          NaN
#
#      hasMegaEvolution Height_m Weight_kg  Catch_Rate       Body_Style
# 0               False     0.71       6.9          45        quadruped
# 1               False     0.99      13.0          45        quadruped
# 2                True     2.01     100.0          45        quadruped
# 3               False     0.61       8.5          45   bipedal_tailed
# 4               False     1.09      19.0          45   bipedal_tailed
# ..                ...      ...       ...         ...              ...
# 716             False     5.79     203.0          45        two_wings
# 717             False     5.00     305.0           3  serpentine_body
# 718              True     0.71       8.8           3        head_arms
# 719             False     0.51       9.0           3        head_only
# 720             False     1.70     195.0           3        quadruped
#
# [721 rows x 23 columns]

# %%
columnas_a_eliminar = ['Color', 'hasGender', 'Egg_group_1', 'Egg_group_2', 'Body_Style']
pokemon2 = pokemon2.drop(columnas_a_eliminar, axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 columnas_a_eliminar = ['Color', 'hasGender', 'Egg_group_1', 'Egg_group_2', 'Body_Style']
# ----> 2 pokemon2 = pokemon2.drop(columnas_a_eliminar, axis=1)
#
# NameError: name 'pokemon2' is not defined

# %%
import pandas as pd
from pokepy import V2Client

# Crear un cliente pokepy
client = V2Client()

# Lista para almacenar los datos de los Pokémon
datos_pokemon = []

# Iterar sobre todos los Pokémon (ID 1 a 898)
for id_pokemon in range(1, 899):
    # Obtener información sobre el Pokémon actual
    pokemon_lista = client.get_pokemon(id_pokemon)
    
    # Iterar sobre la lista de Pokémon obtenida
    for pokemon in pokemon_lista:
        # Extraer los datos relevantes del Pokémon
        datos_pokemon.append({
            "ID": pokemon.id,
            "Nombre": pokemon.name,
            "Altura": pokemon.height,
            "Peso": pokemon.weight,
            "Tipos": [tipo.type.name for tipo in pokemon.types],
            "Habilidades": [habilidad.ability.name for habilidad in pokemon.abilities],
            "Estadisticas": {
                stat.stat.name: stat.base_stat for stat in pokemon.stats
            },
            "Movimientos": [movimiento.move.name for movimiento in pokemon.moves]
        })

# Crear un DataFrame con los datos de los Pokémon
df_pokemon = pd.DataFrame(datos_pokemon)

# Mostrar las primeras filas del DataFrame
df_pokemon
# Out:
#       ID      Nombre  Altura  Peso             Tipos              Habilidades  \
# 0      1   bulbasaur       7    69   [grass, poison]  [overgrow, chlorophyll]
# 1      2     ivysaur      10   130   [grass, poison]  [overgrow, chlorophyll]
# 2      3    venusaur      20  1000   [grass, poison]  [overgrow, chlorophyll]
# 3      4  charmander       6    85            [fire]     [blaze, solar-power]
# 4      5  charmeleon      11   190            [fire]     [blaze, solar-power]
# ..   ...         ...     ...   ...               ...                      ...
# 893  894   regieleki      12  1450        [electric]             [transistor]
# 894  895   regidrago      21  2000          [dragon]            [dragons-maw]
# 895  896   glastrier      22  8000             [ice]         [chilling-neigh]
# 896  897   spectrier      20   445           [ghost]             [grim-neigh]
# 897  898     calyrex      11    77  [psychic, grass]                [unnerve]
#
#                                           Estadisticas  \
# 0    {'hp': 45, 'attack': 49, 'defense': 49, 'speci...
# 1    {'hp': 60, 'attack': 62, 'defense': 63, 'speci...
# 2    {'hp': 80, 'attack': 82, 'defense': 83, 'speci...
# 3    {'hp': 39, 'attack': 52, 'defense': 43, 'speci...
# 4    {'hp': 58, 'attack': 64, 'defense': 58, 'speci...
# ..                                                 ...
# 893  {'hp': 80, 'attack': 100, 'defense': 50, 'spec...
# 894  {'hp': 200, 'attack': 100, 'defense': 50, 'spe...
# 895  {'hp': 100, 'attack': 145, 'defense': 130, 'sp...
# 896  {'hp': 100, 'attack': 65, 'defense': 60, 'spec...
# 897  {'hp': 100, 'attack': 80, 'defense': 80, 'spec...
#
#                                            Movimientos
# 0    [razor-wind, swords-dance, cut, bind, vine-whi...
# 1    [swords-dance, cut, bind, vine-whip, headbutt,...
# 2    [swords-dance, cut, bind, vine-whip, headbutt,...
# 3    [mega-punch, fire-punch, thunder-punch, scratc...
# 4    [mega-punch, fire-punch, thunder-punch, scratc...
# ..                                                 ...
# 893  [body-slam, take-down, thrash, hyper-beam, thu...
# 894  [vice-grip, body-slam, take-down, thrash, bite...
# 895  [swords-dance, stomp, double-kick, tackle, bod...
# 896  [stomp, double-kick, tackle, body-slam, take-d...
# 897  [pound, pay-day, take-down, psybeam, hyper-bea...
#
# [898 rows x 8 columns]

# %%
# import pokebase as pb
# import pandas as pd

# # Crear una lista para almacenar los datos de los Pokémon
# pokemon_data = []

# # Iterar sobre todos los Pokémon disponibles
# for pokemon_id in range(1, 899):  # Hay un total de 898 Pokémon en la Pokédex nacional
#     pokemon = pb.pokemon(pokemon_id)

#     # Obtener los datos del Pokémon actual
#     pokemon_info = {
#         "ID": pokemon_id,
#         "Nombre": pokemon.name,
#         "Altura": pokemon.height,
#         "Peso": pokemon.weight,
#         "Tipos": [tipo.type.name for tipo in pokemon.types],
#         "Habilidades": [habilidad.ability.name for habilidad in pokemon.abilities],
#         "Estadísticas": {stat.stat.name: stat.base_stat for stat in pokemon.stats},
#         "Movimientos": [movimiento.move.name for movimiento in pokemon.moves]
#     }

#     # Agregar los datos del Pokémon a la lista
#     pokemon_data.append(pokemon_info)

# # Crear un DataFrame a partir de la lista de datos de Pokémon
# df_pokemon = pd.DataFrame(pokemon_data)

# # Mostrar el DataFrame
# df_pokemon

# %%
import pandas as pd
# guarda en variables los datasets y su fuente
df_pokemon = pd.DataFrame(datos_pokemon)
fuente_1 = "https://pokeapi.co/"
# df_2 = pd.DataFrame()
# fuente_2 = ""
# df_3 = pd.DataFrame()
# fuente_3 = ""
# df_4 = pd.DataFrame()
# fuente_4 = ""
# df_5 = pd.DataFrame()
# fuente_5 = ""
# ...

# %% [markdown]
# Muestra mediante un head() los principales datasets con los que vas a trabajar

# %%
# Primer dataset
# df_1.head()

# %%
# Siguiente dataset...
# df_2.head()
