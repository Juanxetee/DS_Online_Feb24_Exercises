# %% [markdown]
# <img src='https://static.nationalgeographicla.com/files/styles/image_3200/public/nationalgeographic762774.jpg?w=1600&h=900' width="1500" height="500">

# %% [markdown]
# En esta parte tendrás que hacer dos cosas, crear una presentación sobre el titanic de no más de 6 slides, sin incluir portada, con los siguientes mensajes y su apoyo en datos:
# 1- El titanic fue un accidente con una tasa de mortalidad alta.
# 2- En esa ocasión los datos apoyan que se dio el "Las mujeres y los niños primero", pero...
# 3- ... que la clase en la que se viajes tuvo una influencia significativa y podría explicar...
# 4- ... las diferencias de tasas de supervivencia entre mujeres y niños.
# 5- Además aunque el puerto de embarque parece influir, se podría asumir que lo fue el tipo de pasaje que embarcó en cada uno.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df_titanic = pd.read_csv("./data/titanic.csv")

# %%
# plt.figure(figsize=(8, 6))
df_titanic['survived'].value_counts().plot(kind='bar', color=['red', 'green'])
plt.title('Tasa de Supervivencia vs Mortalidad')
plt.xlabel('Estado')
plt.ylabel('Número de Pasajeros')
plt.savefig('tasa_supervivencia.png') 
plt.show()

# %%
#Diagrama

sns.catplot(x = "alive", y = "age", hue = "who", data = df_titanic, kind = "strip");
plt.title('Mujeres y niños primero')
plt.xlabel('Supervivencia')
plt.ylabel('Edad')
plt.savefig('mujeres_niños.png') 
plt.show();

# %%
# Gráfico de barras apiladas para la proporción de supervivencia por clase de pasajero
grafico= sns.catplot(x= "alive", col = "class", hue = "who", data = df_titanic, kind = "count");
grafico.set_titles('Proporción de Supervivencia por clase de pasajero')
grafico.set_axis_labels('Supervivencia','Número de Pasajeros')

plt.tight_layout()
plt.savefig('proporcion_clase.png') 
plt.show()

# %%
 # Gráfico de barras apiladas para la proporción de pasajeros embarcados por puerto y su supervivencia

sns.countplot(data=df_titanic, x='embarked', hue='survived', palette='muted')
plt.title('Proporción de Supervivencia por Puerto de Embarque')
plt.xlabel('Puerto de Embarque')
plt.ylabel('Número de Pasajeros')
plt.tight_layout()
plt.savefig('puerto.png') 
plt.show()

# %%
# Crear una nueva figura con cuatro ejes
fig, axs = plt.subplots(2, 2, figsize=(10, 8))

# Dibujar cada figura en un eje diferente
axs[0, 0].imshow(plt.imread('tasa_supervivencia.png'))
axs[0, 1].imshow(plt.imread('mujeres_niños.png'))
axs[1, 0].imshow(plt.imread('proporcion_clase.png'))
axs[1, 1].imshow(plt.imread('puerto.png'))

# Ajustar el espacio entre los subgráficos
plt.tight_layout()

# Mostrar la figura
plt.show()
